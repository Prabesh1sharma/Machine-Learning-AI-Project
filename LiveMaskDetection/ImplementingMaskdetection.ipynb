# %%
import cv2
import tensorflow
import keras
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

# %%
model = load_model('model/model_last.h5')
img_width, img_height = 200,200
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# load the cascade face classifier
face_cascade = cv2.CascadeClassifier(r"C:\Users\Acer\anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml")
cap = cv2.VideoCapture(0)
img_count_full = 0
#paramter for text 
#font 
font = cv2.FONT_HERSHEY_SIMPLEX
#org 
org= (1,1)
Class_label = ' '
#fontscale
fonttscale = 0.5
#blue color in BGR
color = (255,0,0)
#line thickness
thickness = 0.5


while cap.isOpened():
    img_count_full +=1
    r,f = cap.read()
    
    if r == True:
        scale = 50
        width = int(f.shape[1] * scale/100)
        height = int(f.shape[0] * scale/100)
        dim = (width,height)
        #resize
        f = cv2.resize(f,dim,interpolation=cv2.INTER_AREA)
        gry_img = cv2.cvtColor(f,cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gry_img,1.1,6)
        #take face then predict class mask or not mask then draw rectangle and text
        img_count = 0
        for(x,y,w,h) in faces:
            org = (x-10,y-10)
            img_count +=1
            color_face = f[y:y+h,x:x+w]
            cv2.imwrite('face/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
            img = load_img('face/input/%d%dface.jpg'%(img_count_full,img_count),target_size=(img_width,img_height))
        
            img = img_to_array(img)/255
            img = np.expand_dims(img,axis=0)
            pred_prob = model.predict(img)
            pred = np.argmax(pred_prob)
        
            if pred==0:
                print("user with mask - predic = ",pred_prob[0][0])
                Class_label="Mask"
                color = (255,0,0)
                cv2.imwrite('face/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
        
            else:
                print("user not wearing  mask - predic = ",pred_prob[0][1])
                Class_label=" No Mask"
                color = (0,255,0)
                cv2.imwrite('face/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
        
            cv2.rectangle(f,(x,y),(x+w,y+h),(0,0,255),3)
            cv2.putText(f, Class_label, org, font, fonttscale, thickness, cv2.LINE_AA)
            cv2.imshow("opencv",f)
        
        if cv2.waitKey(25) & 0xff == ord('p'): 
            break
    else:
        break
        


cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# user with mask - predict = 0.9880954027175903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9985907673835754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.9972586631774902
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 0.9989296793937683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9969133138656616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9969133138656616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 0.9975095987319946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9968864321708679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9982301592826843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.996281087398529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.997602641582489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9965207576751709
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9982522130012512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9982522130012512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.996151864528656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.998531699180603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.9969557523727417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9983910918235779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9983910918235779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9967687129974365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9975411891937256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.9975411891937256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.9983536005020142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9966368675231934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9966368675231934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9967871904373169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9967871904373169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9973938465118408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9971711039543152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.997916042804718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.997916042804718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9935696125030518
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9935696125030518
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.990805447101593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.997368335723877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.997368335723877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.997825026512146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.997788667678833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.997788667678833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.998773992061615
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9948850274085999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9948850274085999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.992763340473175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# user with mask - predict = 0.9979251623153687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9962992072105408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# user with mask - predict = 0.9962992072105408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9955360889434814
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9955360889434814
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9951173067092896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9951173067092896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# user with mask - predict = 0.9920129179954529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.9911304712295532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.9911304712295532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9916165471076965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9965452551841736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9965452551841736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user with mask - predict = 0.9966779947280884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# user with mask - predict = 0.9968377351760864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9969127178192139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.994719386100769
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# user with mask - predict = 0.9980249404907227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.9980249404907227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 0.9927778840065002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9927778840065002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9978381991386414
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9953120946884155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9953120946884155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9976724982261658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# user with mask - predict = 0.9977630376815796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9973338842391968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9973338842391968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9961977601051331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.9953030347824097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9953030347824097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9960938096046448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9982489347457886
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9957956075668335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9977903366088867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.9977903366088867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# user with mask - predict = 0.9973301887512207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.9937620759010315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.9975153207778931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9973203539848328
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# user with mask - predict = 0.9980568289756775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9980568289756775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9975554347038269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.9982321858406067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9982321858406067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9985039234161377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9974055886268616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9974055886268616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9976136684417725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.997795820236206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9973873496055603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9940219521522522
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9970245957374573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9970245957374573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.9983177185058594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.9941686391830444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.9941686391830444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9965967535972595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9980534315109253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9971291422843933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9974602460861206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# user with mask - predict = 0.9970449805259705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.996845543384552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.996845543384552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.996845543384552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9973042011260986
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 0.9985456466674805
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9986734390258789
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user with mask - predict = 0.9969520568847656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.9969520568847656

# %%
import cv2
import tensorflow as tf
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
import os

model = load_model('model/model_last.h5')
img_width, img_height = 200, 200

# Load the cascade face classifier
face_cascade = cv2.CascadeClassifier(r"C:\Users\Acer\anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml")
cap = cv2.VideoCapture(0)
img_count_full = 0

# Parameters for text
font = cv2.FONT_HERSHEY_SIMPLEX
Class_label = ' '
fontscale = 0.5
color = (255, 0, 0)
thickness = 1

while cap.isOpened():
    img_count_full += 1
    ret, frame = cap.read()

    if ret:
        # scale = 50
        # width = int(frame.shape[1] * scale / 100)
        # height = int(frame.shape[0] * scale / 100)
        # dim = (width, height)
        # frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray_img, 1.1, 6)

        img_count = 0
        for (x, y, w, h) in faces:
            org = (x - 10, y - 10)
            img_count += 1
            color_face = frame[y:y+h, x:x+w]
            
            face_dir = 'face/input'
            with_mask_dir = 'face/with_mask'
            without_mask_dir = 'face/without_mask'
            
            os.makedirs(face_dir, exist_ok=True)
            os.makedirs(with_mask_dir, exist_ok=True)
            os.makedirs(without_mask_dir, exist_ok=True)

            face_path = os.path.join(face_dir, f'{img_count_full}{img_count}face.jpg')
            cv2.imwrite(face_path, color_face)

            img = load_img(face_path, target_size=(img_width, img_height))
            img = img_to_array(img) / 255.0
            img = np.expand_dims(img, axis=0)
            pred_prob = model.predict(img)
            pred = np.argmax(pred_prob)

            if pred == 0:
                print(f"user with mask - predict = {pred_prob[0][0]}")
                Class_label = "Mask"
                color = (255, 0, 0)
                # mask_path = os.path.join(with_mask_dir, f'{img_count_full}{img_count}face.jpg')
                # cv2.imwrite(mask_path, color_face)
            else:
                print(f"user not wearing mask - predict = {pred_prob[0][1]}")
                Class_label = "No Mask"
                color = (0, 255, 0)
                # no_mask_path = os.path.join(without_mask_dir, f'{img_count_full}{img_count}face.jpg')
                # cv2.imwrite(no_mask_path, color_face)
            if os.path.exists(face_path):
                os.remove(face_path)
                
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 3)
            cv2.putText(frame, Class_label, org, font, fontscale, color, thickness, cv2.LINE_AA)

        cv2.imshow("opencv", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# user not wearing mask - predict = 0.5095420479774475
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# user not wearing mask - predict = 0.884602427482605
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.947008490562439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9518014788627625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9841995239257812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.8853705525398254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.593882143497467
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# user not wearing mask - predict = 0.7696723341941833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.5843360424041748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.923527181148529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9156369566917419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.9156369566917419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.837870717048645
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# user not wearing mask - predict = 0.9305776953697205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.860332190990448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.889910876750946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.9799460768699646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# user not wearing mask - predict = 0.9897907376289368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# user not wearing mask - predict = 0.9897907376289368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9690355062484741
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# user not wearing mask - predict = 0.5922980308532715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.5260924100875854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9805230498313904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9774850010871887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9716736078262329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9874923229217529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# user not wearing mask - predict = 0.8927298188209534
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# user not wearing mask - predict = 0.8535526394844055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.8535526394844055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.7057072520256042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.5167511105537415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.8918728232383728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.6209768652915955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# user with mask - predict = 0.5574333667755127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.6510232090950012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.5580887794494629
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.5137184858322144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.5030080080032349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.5076861381530762
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# user with mask - predict = 0.5360473990440369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.5935439467430115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# user with mask - predict = 0.6253491044044495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.7516809701919556
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.6568618416786194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# user not wearing mask - predict = 0.639144241809845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.563313901424408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.7254233956336975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.7476977109909058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.5838233828544617
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.5234074592590332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.7334017753601074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.7579021453857422
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.6284590363502502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.5606053471565247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.6038297414779663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.7837781310081482
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# user not wearing mask - predict = 0.936229944229126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# user not wearing mask - predict = 0.9265308380126953
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.6360608339309692
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.8662599325180054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9279338121414185
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.8729320168495178
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9566355347633362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# user not wearing mask - predict = 0.9312698841094971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.7432670593261719
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9906007051467896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9044926166534424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9828652143478394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.8656047582626343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user not wearing mask - predict = 0.9787986874580383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9261782765388489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user not wearing mask - predict = 0.8817688822746277
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9524470567703247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.913875162601471
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user not wearing mask - predict = 0.8830380439758301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.6054868102073669
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9651434421539307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.8785511255264282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9722710847854614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.927510678768158
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.981950044631958
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# user not wearing mask - predict = 0.9900557994842529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9749230146408081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# user not wearing mask - predict = 0.9864712357521057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9423075914382935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.9567063450813293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9626887440681458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9626887440681458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9860246777534485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# user not wearing mask - predict = 0.9272702932357788
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.8111953139305115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# user not wearing mask - predict = 0.9871805310249329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.635391116142273
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.8435628414154053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# user not wearing mask - predict = 0.9895528554916382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9895528554916382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9995094537734985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user not wearing mask - predict = 0.9989542961120605
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# user not wearing mask - predict = 0.9962788224220276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9974555373191833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9966867566108704
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9949526786804199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9976922273635864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9941715598106384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9928382039070129
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9982407093048096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9971053004264832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999998807907104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9970571994781494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.9991214871406555
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9995529055595398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9998682737350464
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.9998682737350464
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# user not wearing mask - predict = 0.9999879598617554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.9999803304672241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user not wearing mask - predict = 0.9999765157699585
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999386072158813
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.998357355594635
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# user with mask - predict = 0.8239070773124695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9947751760482788
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9994584918022156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.9999628067016602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.9913132786750793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9997190833091736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9997190833091736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# user with mask - predict = 0.9999662637710571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9999834299087524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# user with mask - predict = 0.9999834299087524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.996523916721344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.996523916721344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# user not wearing mask - predict = 0.9082159996032715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9082159996032715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9428438544273376
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.886140763759613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9999954700469971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.999977707862854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9988946318626404
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9999594688415527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9548230171203613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9612833261489868
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9676350355148315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.8602108955383301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.81642746925354
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.8451688885688782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.7109545469284058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.8176319599151611
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9336127638816833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.6337956190109253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999995231628418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.8912292718887329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.8912292718887329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.8308716416358948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.9905390739440918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 0.8735984563827515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.8735984563827515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# user with mask - predict = 0.9816480875015259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9816480875015259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# user with mask - predict = 0.9990422129631042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.6919585466384888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.6919585466384888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9030781388282776
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.5420361757278442
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user not wearing mask - predict = 0.7311468124389648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.7311468124389648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# user not wearing mask - predict = 0.801851212978363
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9457800984382629
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.6652330756187439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.6652330756187439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.7978077530860901
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user not wearing mask - predict = 0.7978077530860901
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.84662264585495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.84662264585495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.7395477890968323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9610266089439392
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9592651724815369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user with mask - predict = 0.9592651724815369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user not wearing mask - predict = 0.5297136306762695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.5297136306762695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.922024130821228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9484474658966064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user not wearing mask - predict = 0.9948775172233582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9963917136192322
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# user not wearing mask - predict = 0.9736619591712952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9901651740074158
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9404172301292419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9242007732391357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# user not wearing mask - predict = 0.9275204539299011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9915307760238647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9929323196411133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9983408451080322
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.7764802575111389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.6517015695571899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# user not wearing mask - predict = 0.6517015695571899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9999933242797852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.8675614595413208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# user not wearing mask - predict = 0.8675614595413208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user not wearing mask - predict = 0.9808354377746582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.5029207468032837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.7043606042861938
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.6914796829223633
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.6914796829223633
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9994822144508362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# user not wearing mask - predict = 0.999980092048645
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999291896820068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9999935626983643
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.999995231628418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999922513961792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.6998043060302734
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9999911785125732
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999954700469971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999938011169434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9999934434890747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9999865293502808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9999912977218628
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user not wearing mask - predict = 0.9999761581420898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9999295473098755
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.999950647354126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999186992645264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9999186992645264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9999252557754517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9999239444732666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.999958872795105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.9999637603759766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999637603759766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9999639987945557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9998688697814941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.998551070690155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# user not wearing mask - predict = 0.9998315572738647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9999027252197266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9999027252197266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999130964279175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.9988245368003845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# user not wearing mask - predict = 0.9998495578765869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9966068267822266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.8910517692565918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9999995231628418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.9998644590377808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.9999512434005737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999620914459229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9999960660934448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9999982118606567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# user with mask - predict = 0.9999982118606567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9999992847442627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9999983310699463
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 0.9999803304672241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999923706054688
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9998395442962646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.8572295904159546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9993508458137512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9992963075637817
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9991150498390198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9999936819076538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.9999955892562866
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999189376831055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9999032020568848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.9978750944137573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# user with mask - predict = 0.9992160797119141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999980926513672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9999980926513672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9999070167541504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# user with mask - predict = 0.9997106194496155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999631643295288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999217987060547
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.9999220371246338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.998292863368988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.999966025352478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.999966025352478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9998958110809326
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9997257590293884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.9997257590293884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9999653100967407
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9997429251670837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999147653579712
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9999803304672241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.9999768733978271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9999157190322876
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999886751174927
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 0.9998944997787476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.9967708587646484
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.9995561242103577
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999655485153198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 0.9999693632125854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999043941497803
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9824774861335754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9993124008178711
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9998668432235718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9998528957366943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.9998528957366943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999539852142334
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999707937240601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.999751627445221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9992895126342773
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9973456263542175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9998660087585449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9987175464630127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.996451735496521
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# user not wearing mask - predict = 0.9998283386230469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.9999536275863647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# user not wearing mask - predict = 0.9999668598175049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9999834299087524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9997708201408386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9841377139091492
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user not wearing mask - predict = 0.9991864562034607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.999972939491272
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.9999891519546509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.999880313873291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9998829364776611
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9975854158401489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9632013440132141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# user not wearing mask - predict = 0.9784581065177917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 0.5629558563232422
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.5979753136634827
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.9999761581420898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.9999997615814209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.9999997615814209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9999998807907104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 0.9999998807907104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.9809967279434204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 0.7043046951293945
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.9978175163269043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9977530837059021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9985093474388123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9985093474388123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9993773102760315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9994829893112183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.9999526739120483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9998804330825806
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9998730421066284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.9999014139175415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9999736547470093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999860525131226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9999779462814331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user not wearing mask - predict = 0.9998500347137451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9998500347137451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.999991774559021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# user not wearing mask - predict = 0.9999738931655884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9999642372131348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9997418522834778
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9999097585678101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9998493194580078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9999740123748779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9978082776069641
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9903462529182434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# user not wearing mask - predict = 0.9903462529182434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.76777583360672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.7723188996315002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user with mask - predict = 0.981652021408081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.6821888089179993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.9999861717224121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.999998927116394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user with mask - predict = 0.9715191125869751
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user with mask - predict = 0.9611859321594238
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9993714690208435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.9993307590484619
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user with mask - predict = 0.944342315196991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.5354549288749695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user with mask - predict = 0.6133018732070923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# user with mask - predict = 0.6133018732070923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user with mask - predict = 0.634662389755249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.7050145864486694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# user not wearing mask - predict = 0.7050145864486694
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# user with mask - predict = 0.6136142015457153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user with mask - predict = 0.6961953043937683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user with mask - predict = 0.8913531303405762
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.801892101764679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.801892101764679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9911102056503296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9911102056503296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.7706640958786011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.925247848033905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.9472997188568115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.928493082523346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# user not wearing mask - predict = 0.945570707321167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.967326819896698
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.8997606635093689
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.7606343626976013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.8315178155899048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# user not wearing mask - predict = 0.8896466493606567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9155291318893433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9155291318893433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9037727117538452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9732548594474792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.998963475227356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9950007796287537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9978668093681335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.9910393357276917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# user not wearing mask - predict = 0.9910393357276917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9916024804115295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9974775910377502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9660547375679016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.9738648533821106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9831461310386658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9831461310386658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9445876479148865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# user not wearing mask - predict = 0.9445876479148865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# user not wearing mask - predict = 0.9967412352561951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# user not wearing mask - predict = 0.9963663816452026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# user not wearing mask - predict = 0.9963663816452026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# user not wearing mask - predict = 0.9128328561782837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9654226899147034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# user not wearing mask - predict = 0.9880016446113586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# user not wearing mask - predict = 0.9880016446113586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# user not wearing mask - predict = 0.9986224174499512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# user not wearing mask - predict = 0.9958373308181763
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# user not wearing mask - predict = 0.9979273080825806
